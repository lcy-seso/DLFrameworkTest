# %%
N = 2
D = 4
L = 16
hidden = 16

# %%
indices = []
for j5 in range(2, L + D - 1):
    for j4 in range(max(1, j5 - L + 1), min(j5, D)):
        for j3 in range(0, N):
            indices.append([[j5, j4, j3], [j3, j4, j5 - j4]])

id = 2
no = 0
print(f"hyper plane: {no}")

for i, (ids_t, ids) in enumerate(indices):
    if id != ids_t[0]:
        print("\n")
        id = ids_t[0]
        no += 1
        print(f"hyper plane: {no}")
    print(f"{i}: trans: {ids_t} <--> orig: {ids}; ws: {ids_t[1]}")
# Out:
# hyper plane: 0
# 0: trans: [2, 1, 0] <--> orig: [0, 1, 1]; ws: 1
# 1: trans: [2, 1, 1] <--> orig: [1, 1, 1]; ws: 1
#
#
# hyper plane: 1
# 2: trans: [3, 1, 0] <--> orig: [0, 1, 2]; ws: 1
# 3: trans: [3, 1, 1] <--> orig: [1, 1, 2]; ws: 1
# 4: trans: [3, 2, 0] <--> orig: [0, 2, 1]; ws: 2
# 5: trans: [3, 2, 1] <--> orig: [1, 2, 1]; ws: 2
#
#
# hyper plane: 2
# 6: trans: [4, 1, 0] <--> orig: [0, 1, 3]; ws: 1
# 7: trans: [4, 1, 1] <--> orig: [1, 1, 3]; ws: 1
# 8: trans: [4, 2, 0] <--> orig: [0, 2, 2]; ws: 2
# 9: trans: [4, 2, 1] <--> orig: [1, 2, 2]; ws: 2
# 10: trans: [4, 3, 0] <--> orig: [0, 3, 1]; ws: 3
# 11: trans: [4, 3, 1] <--> orig: [1, 3, 1]; ws: 3
#
#
# hyper plane: 3
# 12: trans: [5, 1, 0] <--> orig: [0, 1, 4]; ws: 1
# 13: trans: [5, 1, 1] <--> orig: [1, 1, 4]; ws: 1
# 14: trans: [5, 2, 0] <--> orig: [0, 2, 3]; ws: 2
# 15: trans: [5, 2, 1] <--> orig: [1, 2, 3]; ws: 2
# 16: trans: [5, 3, 0] <--> orig: [0, 3, 2]; ws: 3
# 17: trans: [5, 3, 1] <--> orig: [1, 3, 2]; ws: 3
#
#
# ...

# %%
indices = []
for j5 in range(2, L + D - 1):
    for j4 in range(max(1, j5 - D + 1), min(j5, L)):
        for j3 in range(0, N):
            indices.append([[j5, j4, j3], [j3, j5 - j4, j4]])

id = 2
no = 0
print(f"hyper plane: {no}")

for i, (ids_t, ids) in enumerate(indices):
    if id != ids_t[0]:
        print("\n")
        id = ids_t[0]
        no += 1
        print(f"hyper plane: {no}")
    print(f"{i}: trans: {ids_t} <--> orig: {ids}, ws: {ids_t[2]}")
# Out:
# hyper plane: 0
# 0: trans: [2, 1, 0] <--> orig: [0, 1, 1], ws: 0
# 1: trans: [2, 1, 1] <--> orig: [1, 1, 1], ws: 1
#
#
# hyper plane: 1
# 2: trans: [3, 1, 0] <--> orig: [0, 2, 1], ws: 0
# 3: trans: [3, 1, 1] <--> orig: [1, 2, 1], ws: 1
# 4: trans: [3, 2, 0] <--> orig: [0, 1, 2], ws: 0
# 5: trans: [3, 2, 1] <--> orig: [1, 1, 2], ws: 1
#
#
# hyper plane: 2
# 6: trans: [4, 1, 0] <--> orig: [0, 3, 1], ws: 0
# 7: trans: [4, 1, 1] <--> orig: [1, 3, 1], ws: 1
# 8: trans: [4, 2, 0] <--> orig: [0, 2, 2], ws: 0
# 9: trans: [4, 2, 1] <--> orig: [1, 2, 2], ws: 1
# 10: trans: [4, 3, 0] <--> orig: [0, 1, 3], ws: 0
# 11: trans: [4, 3, 1] <--> orig: [1, 1, 3], ws: 1
#
#
# hyper plane: 3
# 12: trans: [5, 2, 0] <--> orig: [0, 3, 2], ws: 0
# 13: trans: [5, 2, 1] <--> orig: [1, 3, 2], ws: 1
# 14: trans: [5, 3, 0] <--> orig: [0, 2, 3], ws: 0
# 15: trans: [5, 3, 1] <--> orig: [1, 2, 3], ws: 1
# 16: trans: [5, 4, 0] <--> orig: [0, 1, 4], ws: 0
# 17: trans: [5, 4, 1] <--> orig: [1, 1, 4], ws: 1
#
#
# ...
